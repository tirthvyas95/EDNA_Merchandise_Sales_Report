# %% [markdown]
# Sentiment Analysis Using NLTK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
df = pd.read_excel('C:/Users/tirth/Documents/Projects/EDNA Merchandise Sales Report/Source Files/Onyx Data -DataDNA Dataset Challenge - Merchandise Sales Dataset - January 2025.xlsx')

# %%
print(df.head())
# Out:
#    Order ID Order Date Product ID Product Category Buyer Gender  Buyer Age  \
# 0    189440 2024-07-21     BF1543         Clothing         Male         30
# 1    187385 2024-07-20     BF1543         Clothing         Male         32
# 2    181844 2024-07-21     BF1544            Other       Female         26
# 3    197934 2024-08-19     BF1544            Other         Male         28
# 4    122470 2024-01-06     BF1545            Other       Female         19
#
#   Order Location   Latitude   Longitude International Shipping  Sales Price  \
# 0     New Jersey  39.833851  -74.871826                     No          100
# 1      Las Vegas  36.188110 -115.176468                     No          100
# 2        Cardiff  51.481583   -3.179090                    Yes            9
# 3     Pittsburgh  40.440620  -79.995890                     No            9
# 4          Miami  25.761681  -80.191788                     No           10
#
#    Shipping Charges  Sales per Unit  Quantity  Total Sales  Rating  \
# 0                 0             100         1          100       4
# 1                 0             100         1          100       3
# 2                40              49         1           49       2
# 3                 0               9         2           18       3
# 4                 0              10         3           30       5
#
#                                               Review
# 0   The delivery team handled the product with care.
# 1  Had slight delays but the product was in good ...
# 2                                    Waste of Money.
# 3  Had slight delays but the product was in good ...
# 4    Lack of delivery delays is greatly appreciated.

# %%
print(df.shape)
# Out:
# (7394, 17)

# %%
ax = df['Rating'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %%
example = df['Review'][50]
print(example)
# Out:
# Premium quality as usual.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tokens = nltk.word_tokenize(example)
#       2 tokens[:10]
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\tirth/nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\share\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\lib\\nltk_data'
#     - 'C:\\Users\\tirth\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tirth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tokens = nltk.word_tokenize(example)
#       2 tokens[:10]
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\tirth/nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\share\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\lib\\nltk_data'
#     - 'C:\\Users\\tirth\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\tirth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['Premium', 'quality', 'as', 'usual', '.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\tirth\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('Premium', 'JJ'),
#  ('quality', 'NN'),
#  ('as', 'IN'),
#  ('usual', 'JJ'),
#  ('.', '.')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 entities = nltk.chunk.ne_chunk(tagged)
#       2 entities.pprint()
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\__init__.py:192, in ne_chunk(tagged_tokens, binary)
#     190     chunker = ne_chunker(fmt="binary")
#     191 else:
# --> 192     chunker = ne_chunker()
#     193 return chunker.parse(tagged_tokens)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\__init__.py:174, in ne_chunker(fmt)
#     170 def ne_chunker(fmt="multiclass"):
#     171     """
#     172     Load NLTK's currently recommended named entity chunker.
#     173     """
# --> 174     return Maxent_NE_Chunker(fmt)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\named_entity.py:329, in Maxent_NE_Chunker.__init__(self, fmt)
#     326 from nltk.data import find
#     328 self._fmt = fmt
# --> 329 self._tab_dir = find(f"chunkers/maxent_ne_chunker_tab/english_ace_{fmt}/")
#     330 self.load_params()
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource maxent_ne_chunker_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('maxent_ne_chunker_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load chunkers/maxent_ne_chunker_tab/english_ace_multiclass/
#
#   Searched in:
#     - 'C:\\Users\\tirth/nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\share\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\lib\\nltk_data'
#     - 'C:\\Users\\tirth\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\tirth\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource words not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('words')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/words.zip/words/
#
#   Searched in:
#     - 'C:\\Users\\tirth/nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\share\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\lib\\nltk_data'
#     - 'C:\\Users\\tirth\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 entities = nltk.chunk.ne_chunk(tagged)
#       2 entities.pprint()
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\__init__.py:193, in ne_chunk(tagged_tokens, binary)
#     191 else:
#     192     chunker = ne_chunker()
# --> 193 return chunker.parse(tagged_tokens)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\named_entity.py:134, in NEChunkParser.parse(self, tokens)
#     130 def parse(self, tokens):
#     131     """
#     132     Each token should be a pos-tagged word
#     133     """
# --> 134     tagged = self._tagger.tag(tokens)
#     135     tree = self._tagged_to_parse(tagged)
#     136     return tree
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tag\sequential.py:61, in SequentialBackoffTagger.tag(self, tokens)
#      59 tags = []
#      60 for i in range(len(tokens)):
# ---> 61     tags.append(self.tag_one(tokens, i, tags))
#      62 return list(zip(tokens, tags))
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tag\sequential.py:81, in SequentialBackoffTagger.tag_one(self, tokens, index, history)
#      79 tag = None
#      80 for tagger in self._taggers:
# ---> 81     tag = tagger.choose_tag(tokens, index, history)
#      82     if tag is not None:
#      83         break
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tag\sequential.py:646, in ClassifierBasedTagger.choose_tag(self, tokens, index, history)
#     644 def choose_tag(self, tokens, index, history):
#     645     # Use our feature detector to get the featureset.
# --> 646     featureset = self.feature_detector(tokens, index, history)
#     648     # Use the classifier to pick a tag.  If a cutoff probability
#     649     # was specified, then check that the tag's probability is
#     650     # higher than that cutoff first; otherwise, return None.
#     651     if self._cutoff_prob is None:
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\tag\sequential.py:693, in ClassifierBasedTagger.feature_detector(self, tokens, index, history)
#     683 def feature_detector(self, tokens, index, history):
#     684     """
#     685     Return the feature detector that this tagger uses to generate
#     686     featuresets for its classifier.  The feature detector is a
#    (...)    691     See ``classifier()``
#     692     """
# --> 693     return self._feature_detector(tokens, index, history)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\named_entity.py:108, in NEChunkParserTagger._feature_detector(self, tokens, index, history)
#      97     nextnextpos = tokens[index + 2][1].lower()
#      99 # 89.6
#     100 features = {
#     101     "bias": True,
#     102     "shape": shape(word),
#     103     "wordlen": len(word),
#     104     "prefix3": word[:3].lower(),
#     105     "suffix3": word[-3:].lower(),
#     106     "pos": pos,
#     107     "word": word,
# --> 108     "en-wordlist": (word in self._english_wordlist()),
#     109     "prevtag": prevtag,
#     110     "prevpos": prevpos,
#     111     "nextpos": nextpos,
#     112     "prevword": prevword,
#     113     "nextword": nextword,
#     114     "word+nextpos": f"{word.lower()}+{nextpos}",
#     115     "pos+prevtag": f"{pos}+{prevtag}",
#     116     "shape+prevtag": f"{prevshape}+{prevtag}",
#     117 }
#     119 return features
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\chunk\named_entity.py:59, in NEChunkParserTagger._english_wordlist(self)
#      56 except AttributeError:
#      57     from nltk.corpus import words
# ---> 59     self._en_wordlist = set(words.words("en-basic"))
#      60     wl = self._en_wordlist
#      61 return wl
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\corpus\util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File C:\ProgramData\anaconda3\envs\test\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource words not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('words')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/words
#
#   Searched in:
#     - 'C:\\Users\\tirth/nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\share\\nltk_data'
#     - 'C:\\ProgramData\\anaconda3\\envs\\test\\lib\\nltk_data'
#     - 'C:\\Users\\tirth\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\tirth\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S Premium/JJ quality/NN as/IN usual/JJ ./.)

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in C:\ProgramData\anaconda3\envs\test\Lib\site-packages (4.67.3)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\envs\test\Lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\tirth\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Review']
    myid = row['Order ID']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/7394 [00:00<?, ?it/s]

# %%
pd.DataFrame(res)
# Out:
#           189440  187385  181844  197934  122470  199680  130929  164427  \
# neg       0.0000  0.0000  0.5830  0.0000  0.2110     0.0     0.0     0.0
# neu       0.6860  0.7000  0.4170  0.7000  0.4590     1.0     1.0     1.0
# pos       0.3140  0.3000  0.0000  0.3000  0.3300     0.0     0.0     0.0
# compound  0.4939  0.5927 -0.4215  0.5927  0.3167     0.0     0.0     0.0
#
#           149510  176280  ...  131694  127447  143594  195098  161930  136943  \
# neg       0.2110  0.0000  ...  0.4380  0.0000     0.0  0.0000  0.0000     0.0
# neu       0.4590  0.5450  ...  0.5620  0.6860     1.0  0.5270  0.5450     1.0
# pos       0.3300  0.4550  ...  0.0000  0.3140     0.0  0.4730  0.4550     0.0
# compound  0.3167  0.8176  ... -0.6652  0.4939     0.0  0.5563  0.8176     0.0
#
#           172276  160191  195268  138160
# neg       0.0000  0.5830     0.0  0.3330
# neu       0.5820  0.4170     1.0  0.6670
# pos       0.4180  0.0000     0.0  0.0000
# compound  0.5563 -0.4215     0.0 -0.3612
#
# [4 rows x 7394 columns]

# %%
vaders = pd.DataFrame(res).T

# %%
vaders
# Out:
#           neg    neu    pos  compound
# 189440  0.000  0.686  0.314    0.4939
# 187385  0.000  0.700  0.300    0.5927
# 181844  0.583  0.417  0.000   -0.4215
# 197934  0.000  0.700  0.300    0.5927
# 122470  0.211  0.459  0.330    0.3167
# ...       ...    ...    ...       ...
# 136943  0.000  1.000  0.000    0.0000
# 172276  0.000  0.582  0.418    0.5563
# 160191  0.583  0.417  0.000   -0.4215
# 195268  0.000  1.000  0.000    0.0000
# 138160  0.333  0.667  0.000   -0.3612
#
# [7394 rows x 4 columns]

# %%
vaders = vaders.reset_index().rename(columns={'index': 'Order ID'})
vaders = vaders.merge(df, how='left')

# %%
vaders
# Out:
#       level_0  Order ID    neg    neu    pos  compound Order Date Product ID  \
# 0           0    189440  0.000  0.686  0.314    0.4939 2024-07-21     BF1543
# 1           1    187385  0.000  0.700  0.300    0.5927 2024-07-20     BF1543
# 2           2    181844  0.583  0.417  0.000   -0.4215 2024-07-21     BF1544
# 3           3    197934  0.000  0.700  0.300    0.5927 2024-08-19     BF1544
# 4           4    122470  0.211  0.459  0.330    0.3167 2024-01-06     BF1545
# ...       ...       ...    ...    ...    ...       ...        ...        ...
# 7389     7389    136943  0.000  1.000  0.000    0.0000 2023-12-10     BF1548
# 7390     7390    172276  0.000  0.582  0.418    0.5563 2024-01-24     BF1546
# 7391     7391    160191  0.583  0.417  0.000   -0.4215 2023-12-19     BF1552
# 7392     7392    195268  0.000  1.000  0.000    0.0000 2023-12-07     BF1555
# 7393     7393    138160  0.333  0.667  0.000   -0.3612 2024-10-23     BF1544
#
#      Product Category Buyer Gender  ...   Latitude   Longitude  \
# 0            Clothing         Male  ...  39.833851  -74.871826
# 1            Clothing         Male  ...  36.188110 -115.176468
# 2               Other       Female  ...  51.481583   -3.179090
# 3               Other         Male  ...  40.440620  -79.995890
# 4               Other       Female  ...  25.761681  -80.191788
# ...               ...          ...  ...        ...         ...
# 7389         Clothing         Male  ...  36.188110 -115.176468
# 7390         Clothing       Female  ...  53.483959    2.244644
# 7391        Ornaments         Male  ...  25.761681  -80.191788
# 7392            Other         Male  ...  25.761681  -80.191788
# 7393            Other       Female  ...  41.505493  -81.681290
#
#       International Shipping  Sales Price Shipping Charges  Sales per Unit  \
# 0                         No          100                0             100
# 1                         No          100                0             100
# 2                        Yes            9               40              49
# 3                         No            9                0               9
# 4                         No           10                0              10
# ...                      ...          ...              ...             ...
# 7389                      No           65                0              65
# 7390                     Yes          118               40             158
# 7391                      No           45                0              45
# 7392                      No           23                0              23
# 7393                      No            9                0               9
#
#       Quantity  Total Sales  Rating  \
# 0            1          100       4
# 1            1          100       3
# 2            1           49       2
# 3            2           18       3
# 4            3           30       5
# ...        ...          ...     ...
# 7389         1           65       4
# 7390         1          158       4
# 7391         1           45       2
# 7392         1           23       5
# 7393         1            9       1
#
#                                                  Review
# 0      The delivery team handled the product with care.
# 1     Had slight delays but the product was in good ...
# 2                                       Waste of Money.
# 3     Had slight delays but the product was in good ...
# 4       Lack of delivery delays is greatly appreciated.
# ...                                                 ...
# 7389  The product was affordable here compared to ot...
# 7390  Exquisite craftsmanship here is absolutely app...
# 7391                                    Waste of Money.
# 7392  The product was affordable here compared to ot...
# 7393            Careless handling by the delivery team.
#
# [7394 rows x 22 columns]

# %%
vaders.head()
# Out:
#    level_0  Order ID    neg    neu    pos  compound Order Date Product ID  \
# 0        0    189440  0.000  0.686  0.314    0.4939 2024-07-21     BF1543
# 1        1    187385  0.000  0.700  0.300    0.5927 2024-07-20     BF1543
# 2        2    181844  0.583  0.417  0.000   -0.4215 2024-07-21     BF1544
# 3        3    197934  0.000  0.700  0.300    0.5927 2024-08-19     BF1544
# 4        4    122470  0.211  0.459  0.330    0.3167 2024-01-06     BF1545
#
#   Product Category Buyer Gender  ...   Latitude   Longitude  \
# 0         Clothing         Male  ...  39.833851  -74.871826
# 1         Clothing         Male  ...  36.188110 -115.176468
# 2            Other       Female  ...  51.481583   -3.179090
# 3            Other         Male  ...  40.440620  -79.995890
# 4            Other       Female  ...  25.761681  -80.191788
#
#    International Shipping  Sales Price Shipping Charges  Sales per Unit  \
# 0                      No          100                0             100
# 1                      No          100                0             100
# 2                     Yes            9               40              49
# 3                      No            9                0               9
# 4                      No           10                0              10
#
#    Quantity  Total Sales  Rating  \
# 0         1          100       4
# 1         1          100       3
# 2         1           49       2
# 3         2           18       3
# 4         3           30       5
#
#                                               Review
# 0   The delivery team handled the product with care.
# 1  Had slight delays but the product was in good ...
# 2                                    Waste of Money.
# 3  Had slight delays but the product was in good ...
# 4    Lack of delivery delays is greatly appreciated.
#
# [5 rows x 22 columns]

# %%
ax = sns.barplot(data=vaders, x='Rating', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Rating', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Rating', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Rating', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()
